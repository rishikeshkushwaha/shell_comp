# %%
import pandas as pd
import numpy as np

# %%
demand_history = pd.read_csv("Demand_History.csv")

# %%
existing_ev = pd.read_csv("exisiting_EV_infrastructure_2018.csv")

# %%
from keplergl import KeplerGl
map_2 = KeplerGl(height=400, data={"data": existing_ev})
map_2
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(data={'data':     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0           …

# %%
map_2.save_to_html(file_name='first_map.html')
# Out:
# Map saved to first_map.html!

# %%
import matplotlib.pyplot as plt
plt.scatter(x=existing_ev['x_coordinate'], y=existing_ev['y_coordinate'])
plt.show()

# %%
demand_history['y_coordinate'].unique()
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#        11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#        22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#        33.5, 34.5, 35.5, 36.5, 37.5, 38.5, 39.5, 40.5, 41.5, 42.5, 43.5,
#        44.5, 45.5, 46.5, 47.5, 48.5, 49.5, 50.5, 51.5, 52.5, 53.5, 54.5,
#        55.5, 56.5, 57.5, 58.5, 59.5, 60.5, 61.5, 62.5, 63.5])

# %%
demand_history['x_coordinate'].unique()
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#        11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5,
#        22.5, 23.5, 24.5, 25.5, 26.5, 27.5, 28.5, 29.5, 30.5, 31.5, 32.5,
#        33.5, 34.5, 35.5, 36.5, 37.5, 38.5, 39.5, 40.5, 41.5, 42.5, 43.5,
#        44.5, 45.5, 46.5, 47.5, 48.5, 49.5, 50.5, 51.5, 52.5, 53.5, 54.5,
#        55.5, 56.5, 57.5, 58.5, 59.5, 60.5, 61.5, 62.5, 63.5])

# %%
x = np.arange(0.5, 64, 1)
y = np.arange(0.5, 64, 1)

fig = plt.figure()
ax = fig.gca()
ax.set_xticks(np.arange(0.5, 64, 1))
ax.set_yticks(np.arange(0.5, 64, 1))
plt.grid()
plt.show()

# %%
temp  = demand_history[['x_coordinate','y_coordinate','2010']].pivot(index='x_coordinate', columns='y_coordinate', values='2010').reset_index()

# %%
import seaborn as sns

# %%
del temp['x_coordinate']

# %%
sns.heatmap(temp)
# Out:
# <AxesSubplot:xlabel='y_coordinate'>

# %%
temp.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# ...

# %%
plt.pcolor(temp)

# %%
sns.heatmap(temp, cmap='RdYlGn_r', linewidths=0.5, )
# Out:
# <AxesSubplot:xlabel='y_coordinate'>

# %%
years = demand_history.columns[3:]

# %%
for year in years:
    print(year)
    temp  = demand_history[['x_coordinate','y_coordinate',year]].pivot(index='x_coordinate', columns='y_coordinate', values=year).reset_index()
    del temp['x_coordinate']
    sns.heatmap(temp, cmap='RdYlGn_r', linewidths=0.5)
    plt.show()
# Out:
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
